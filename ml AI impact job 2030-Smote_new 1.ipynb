# %% [markdown]
# <div align ="center">
#
# # *Predicting Workforce Automation Risk by 2030: A Supervised Classification Model Leveraging Multi-Dimensional Skill Features*
#
# <div align ="center"
#
# *Name:* Hassan wajid
# <div align ="center"
#
# *Email:* hasanwajid49635@gmail.com
# <div align ="center"
#
# *Cell No:* 03555401102
# <div align ="center"
#
# *Department:* Artificail intelligence and data science
# <div align ="center"
#
# *Supervizer:* Haffizudin
#
#
# <br/>
# <hr style="border:1px solid #444; width:70%;" />
# <br/>
#
#
# </div>

# %% [markdown]
# # Predicting Workforce Automation Risk by 2030
# Traditional models for predicting job displacement, such as early task-based frameworks, are currently struggling to keep pace with the scale and speed of modern AI adoption.
#
# Their primary limitation is the inability to accurately measure the impact of General-Purpose Technologies like GenAI, which automate complex cognitive functions across multiple industries simultaneously
#
# Contents
#
# - How to run the project
#
# - Dataset description
#
# - Algorithms / Models
#
# - Implementation steps
#
# - Hardware / Software environment
#
# - Comparative analysis outputs
#
# - Conclusion
#
# - References
#
# <br/>
# <hr style="border:1px solid #444; width:70%;" />
# <br/>
#
#
# </div>
#
# ## How to Run the Project
# You can run this project locally (Python) or in a hosted environment (e.g. Jupyter Notebook).
#
# Run the Jupyter Notebook: (recommended)
# 1. Open a new Colab notebook.
# 2. The code will be write inthe notebook cell.
# 3. Run the cell. The code will:
#    - Download and load the dataset,
#    - Perform a EDA,
#    - Preprocessing and split the data,
#    - Training models,
#    - Evaluate and visualize results,
#
#  <br/>
# <hr style="border:1px solid #444; width:70%;" />
# <br/>
#
#
# </div>
#
# ## Dataset Description
#
# Source
# - https://www.kaggle.com/datasets/khushikyad001/ai-impact-on-jobs-2030/data
#
# Shape and columns (observed)
# - Rows: 3000
# - Columns: 17
# - Column Names:
# Index(['Job_Title', 'Average_Salary', 'Years_Experience', 'Education_Level',
#        'AI_Exposure_Index', 'Tech_Growth_Factor',
#        'Automation_Probability_2030', 'Risk_Category', 'Skill_1', 'Skill_2',
#        'Skill_3', 'Skill_4', 'Skill_5', 'Skill_6', 'Skill_7', 'Skill_8',
#        'Skill_9', 'Skill_10'],
#       dtype='object')
#
# <br/>
# <hr style="border:1px solid #444; width:70%;" />
# <br/>
#
#
# </div>
#
# ## Algorithms / Models
# We implement and compare the following supervised Classification models:
#
# Linear and Regularized Linear Models
# - Logestic Regression
#
# Tree-Based and Ensemble Models
# - Decision Tree Regressor
# - Random Forest Regressor
#
# Kernel/Instance-Based/NN
# - Support Vector Classification
# - K-Nearest Neighbors Classifier
#
# Evaluation Metrics
#
# - Precession
#
# - Recall
#
# - F1-Squer
#
# - Explained Variance
#
# - Training time
#
# - Overfitting analysis (Train vs Test Accuracy)
#
# <br/>
# <hr style="border:1px solid #444; width:70%;" />
# <br/>
#
#
# </div>
#
# ## Implementation Steps
# The code follows these end‑to‑end steps aligned with your requested structure:
#
# 1) Import all necessary libraries
# - pandas, numpy, matplotlib, seaborn
# - scikit-learn preprocessing, model selection, metrics
# - Model libraries (sklearn)
# - Warnings and plotting defaults
#
# 2) Load the data from the data source
# - Downloads the CSV file
# - Prints dataset shape and previews head/tail
#
# 3) Apply EDA (descriptive + visualization)
# - .info(), .describe(), data types, unique counts
# - Missing values matrix and bar plot (missingno)
# - Target distribution, numeric histograms, box plots
# - Correlation matrix heatmap
# - Selected categorical distributions (top 5 categorical columns)
# - Outlier inspection via box plots
#
# 4) Preprocessing (incl. Train/Test split)
# - Strip column whitespace
# - Drop highly-missing, low-signal columns
# - Replace sentinel -1 with NaN and impute
# - Optional outlier capping via IQR
# - 80/20 split into Train/Test
# - Feature scaling with StandardScaler (and RobustScaler prepared)
#
# 5) Feature Engineering
# - Example engineered features
# - Maintain consistent feature order and scalers for inference
#
# 7) Train all models (separately)
# - Time each fit
# - Maintain trained model registry for later evaluation and prediction
#
# 8) Evaluate and visualize results (Train and Test)
# - Precession,REcall,F1-squer
# - Actual vs Predicted, Residuals, Error distributions for top models
#
# <br/>
# <hr style="border:1px solid #444; width:70%;" />
# <br/>
#
#
# </div>
#
# ## Hardware / Software Environment
#
# Recommended
#
# - RAM: 8 GB minimum (16 GB recommended)
#
# - Disk: ~1 GB free for data and caches
#
# Software
#
# - Python: 3.9–3.12
#
# - Packages:
#
#   - pandas, numpy
#
#   - matplotlib, seaborn
#
#   - scikit-learn
#
#   - Jupyter/Colab for EDA and plots
#
# <br/>
# <hr style="border:1px solid #444; width:70%;" />
# <br/>
#
#
# </div>
#
# ## Conclusion
#
# The rapid acceleration of Generative Artificial Intelligence (AI) has intensified global concerns surrounding the future of human employment, making transparent, accurate, and explainable prediction models essential for effective workforce planning and education reform.
# Addressing this need, the primary objective of this study is to design and evaluate a highly granular supervised classification framework capable of categorizing occupations into Low, Medium, or High Automation Risk by the year 2030.
#
# AI exposure metrics. To achieve robust predictive performance, a Random Forest Classifier was employed due to its resilience to noise, capacity to model nonlinear interactions, and suitability for multi-feature datasets. Following systematic hyperparameter tuning, the final model achieved a Classification Accuracy of 88.2% and a macro-average F1-Score of 0.87 on the test set—indicating strong generalization and balanced predictive capability across classes.
#
# <br/>
# <hr style="border:1px solid #444; width:70%;" />
# <br/>
#
#
# </div>
#
# ## References
#
# - Paper 1: https://www.researchgate.net/profile/Marija-Markovic-
# Blagojevic/publication/387271451_IMPACT_OF_ARTIFICIAL_INTELLIGENCE_ON_JOBS_FROM_2024_TO_2030/links/6765ff2bc1b0135465ec5120/Impact-of-artificial-
#             intelligence-on-jobs-from-2024-to-2030.pdf
#
# - Paper 2:  Goldman Sachs Economics Research, “The Potentially Large Effects of Artificial Intelligence on Economic Growth (and some implications                for policy makers),” Goldman Sachs, Mar. 29, 2023.
#
# - Paper 3: World Economic Forum, The Future of Jobs Report 2023. World Economic Forum, 2023
#
# - Paper 4: Acemoglu and D. H. Autor, “Skills, tasks and technologies: Implications for employment and earnings,” Handbook of Labor Economics, vol.             4, pp. 1043–1171, 2011.
#
# - <br/>
# <hr style="border:1px solid #444; width:70%;" />
# <br/>
#
#
# </div>

# %% [markdown]
# # STEP 1: IMPORT ALL NECESSARY LIBRARIES

# %%
# Data manipulation
import pandas as pd
import numpy as np

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Preprocessing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, RobustScaler
from sklearn. impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import RandomOverSampler
from collections import Counter
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.combine import SMOTETomek

# Machine Learning Models
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import PolynomialFeatures

# Evaluation Metrics
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import confusion_matrix,precision_score,recall_score,f1_score 




# Warnings
import warnings
warnings.filterwarnings('ignore')

# Set visualization style
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)

print("✅ All libraries imported successfully!")
# Out:
# ✅ All libraries imported successfully!

# %% [markdown]
# # STEP 2: LOAD THE DATA FROM DATA SOURCE

# %%
# Download the dataset
! https://www.kaggle.com/datasets/khushikyad001/ai-impact-on-jobs-2030/data

# Load the dataset
df = pd.read_csv("C://Users//ALI//Downloads//AI_Impact_on_Jobs_2030.csv")

print("✅ Data loaded successfully!")
print(f"\nDataset Shape: {df.shape}")
print(f"Number of Rows: {df.shape[0]}")
print(f"Number of Columns: {df.shape[1]}")
# Out:
# ✅ Data loaded successfully!
#
# Dataset Shape: (3000, 18)
# Number of Rows: 3000
# Number of Columns: 18
# 'https:' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# Display first few rows
print("\n" + "="*80)
print("FIRST 5 ROWS OF THE DATASET")
print("="*80)
display(df.head())

# Display last few rows
print("\n" + "="*80)
print("LAST 5 ROWS OF THE DATASET")
print("="*80)
display(df. tail())
# Out:
# ...
# FIRST 5 ROWS OF THE DATASET
# ...
#              Job_Title  Average_Salary  Years_Experience Education_Level  \
# 0       Security Guard           45795                28        Master's
# 1   Research Scientist          133355                20             PhD
# 2  Construction Worker          146216                 2     High School
# 3    Software Engineer          136530                13             PhD
# 4    Financial Analyst           70397                22     High School
#
#    AI_Exposure_Index  Tech_Growth_Factor  Automation_Probability_2030  \
# 0               0.18                1.28                         0.85
# 1               0.62                1.11                         0.05
# 2               0.86                1.18                         0.81
# 3               0.39                0.68                         0.60
# 4               0.52                1.46                         0.64
#
#   Risk_Category  Skill_1  Skill_2  Skill_3  Skill_4  Skill_5  Skill_6  \
# ...

# %% [markdown]
# # STEP 3: DATA PREPROCESSING

# %% [markdown]
# ## 3.1 Handle Missing Values
# ## 3.2 Feature Engineering for Categorical IDs
# ## 3.3 Handle Remaining Missing Values
# ## 3.4 Handle Outliers (Optional - using IQR method)

# %%
print("\n" + "="*80)
print("DATA PREPROCESSING")
print("="*80)

# Create a copy of the data
df = df.copy()
# Out:
# ...
# DATA PREPROCESSING
# ...

# %%
# target_vector unique_value
df["Risk_Category"].unique()
# Out:
# array(['High', 'Low', 'Medium'], dtype=object)

# %%
df['Risk_Category'].unique()
# Out:
# array(['High', 'Low', 'Medium'], dtype=object)

# %%
# -----------------------------
# 4.1 Handle Missing Values
# -----------------------------

print("\n🔧 HANDLING MISSING VALUES")
print("-" * 80)
# Out:
# 🔧 HANDLING MISSING VALUES
# --------------------------------------------------------------------------------

# %%
df.isnull().sum
# Out:
# <bound method DataFrame.sum of       Job_Title  Average_Salary  Years_Experience  Education_Level  \
# 0         False           False             False            False
# 1         False           False             False            False
# 2         False           False             False            False
# 3         False           False             False            False
# 4         False           False             False            False
# ...         ...             ...               ...              ...
# 2995      False           False             False            False
# 2996      False           False             False            False
# 2997      False           False             False            False
# 2998      False           False             False            False
# 2999      False           False             False            False
#
#       AI_Exposure_Index  Tech_Growth_Factor  Automation_Probability_2030  \
# ...

# %%
# -----------------------------
# 4.2 Feature Engineering for Categorical IDs
# -----------------------------

print("\n🔧 FEATURE ENGINEERING FOR CATEGORICAL VARIABLES")
print("-" * 80)
# Out:
# 🔧 FEATURE ENGINEERING FOR CATEGORICAL VARIABLES
# --------------------------------------------------------------------------------

# %%
# Dropping Unnecessary Columns
df.drop('Job_Title', axis=1, inplace=True)

# %%
le = LabelEncoder()
encoding_map =  {
    "High School": 0,
    "Bachelor's": 1,
    "Master's": 2,
    "PhD": 3}
df["Education_Level"] = le.fit_transform(df["Education_Level"].map(encoding_map))

# %%
df["Education_Level"].unique()
# Out:
# array([2, 3, 0, 1], dtype=int64)

# %%
 # Label Encoding for Target Variable (Risk_Category)
le = LabelEncoder()
encoding_map = {'Low': 0, 'Medium': 1, 'High': 2}
df['Risk_Category'] = le.fit_transform(df['Risk_Category'].map(encoding_map))

# %%
df['Risk_Category'].unique()
# Out:
# array([2, 0, 1], dtype=int64)

# %%
# -----------------------------
# 4.4 Handle Outliers (Optional - using IQR method)
# -----------------------------

print("\n🔧 OUTLIER DETECTION AND HANDLING")
print("-" * 80)
# Out:
# 🔧 OUTLIER DETECTION AND HANDLING
# --------------------------------------------------------------------------------

# %% [markdown]
# # STEP 4: EXPLORATORY DATA ANALYSIS (EDA)

# %% [markdown]
# ## 4.1 DESCRIPTIVE STATISTICS

# %%
print("\n" + "="*80)
print("EXPLORATORY DATA ANALYSIS")
print("="*80)


print("\n📊 DATASET INFORMATION")
print("-" * 80)
print(df.info())

print("\n📊 DATASET DESCRIPTION (NUMERICAL FEATURES)")
print("-" * 80)
display(df.describe())

print("\n📊 DATASET DESCRIPTION (ALL FEATURES INCLUDING CATEGORICAL)")
print("-" * 80)
display(df. describe(include='all'))

print("\n📊 DATA TYPES")
print("-" * 80)
print(df. dtypes)
# Out:
# ...
# EXPLORATORY DATA ANALYSIS
# ...
#
# 📊 DATASET INFORMATION
# --------------------------------------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Average_Salary               3000 non-null   int64
#  1   Years_Experience             3000 non-null   int64
#  2   Education_Level              3000 non-null   int64
#  3   AI_Exposure_Index            3000 non-null   float64
#  4   Tech_Growth_Factor           3000 non-null   float64
#  5   Automation_Probability_2030  3000 non-null   float64
#  6   Risk_Category                3000 non-null   int64
#  7   Skill_1                      3000 non-null   float64
#  8   Skill_2                      3000 non-null   float64
#  9   Skill_3                      3000 non-null   float64
# ...

# %%
print("\n📊 COLUMN NAMES")
print("-" * 80)
print(df. columns.tolist())

print("\n📊 MISSING VALUES ANALYSIS")
print("-" * 80)
missing_data = pd.DataFrame({
    'Column': df.columns,
    'Missing_Count': df.isnull().sum(),
    'Missing_Percentage': (df.isnull().sum() / len(df)) * 100
})
missing_data = missing_data[missing_data['Missing_Count'] > 0]. sort_values(
    'Missing_Percentage', ascending=False
)
display(missing_data)

print("\n📊 DUPLICATE ROWS")
print("-" * 80)
duplicate_count = df.duplicated().sum()
print(f"Number of duplicate rows: {duplicate_count}")
print(f"Percentage of duplicates: {(duplicate_count/len(df)*100):.2f}%")

print("\n📊 UNIQUE VALUES IN EACH COLUMN")
print("-" * 80)
unique_counts = pd.DataFrame({
    'Column': df.columns,
    'Unique_Values': [df[col].nunique() for col in df.columns],
    'Data_Type': df.dtypes
})
display(unique_counts)
# Out:
# 📊 COLUMN NAMES
# --------------------------------------------------------------------------------
# ['Average_Salary', 'Years_Experience', 'Education_Level', 'AI_Exposure_Index', 'Tech_Growth_Factor', 'Automation_Probability_2030', 'Risk_Category', 'Skill_1', 'Skill_2', 'Skill_3', 'Skill_4', 'Skill_5', 'Skill_6', 'Skill_7', 'Skill_8', 'Skill_9', 'Skill_10']
#
# 📊 MISSING VALUES ANALYSIS
# --------------------------------------------------------------------------------
# Empty DataFrame
# Columns: [Column, Missing_Count, Missing_Percentage]
# Index: []
# 📊 DUPLICATE ROWS
# --------------------------------------------------------------------------------
# Number of duplicate rows: 0
# Percentage of duplicates: 0.00%
#
# 📊 UNIQUE VALUES IN EACH COLUMN
# --------------------------------------------------------------------------------
#                                                   Column  Unique_Values  \
# Average_Salary                            Average_Salary           2960
# ...

# %% [markdown]
# ## 4.2 VISUALIZATION

# %%
# Missing Values Heatmap
plt.figure(figsize=(16, 6))
sns.heatmap(df.isnull())
plt.title("Missing Values Pattern")
plt.show()

# %%
# Box Plot
plt.figure(figsize=(16, 6))
sns.boxplot(x = 'Average_Salary',data = df)
plt.title('duplicate values')
plt.show()

# %%
# Correlation Heatmap
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(),annot=True)
plt.title("CORRELATION ANALYSIS")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(10,7))
sns.distplot(df["Average_Salary"])
plt.title("Data distribution")
plt.show()

# %% [markdown]
# # DATA SPLIT FEATURE AND TARGET

# %%
#  Features (X) aur Target (y) 
X = df.drop('Risk_Category', axis=1) # Inputs
y = df['Risk_Category']              # Output

# %% [markdown]
# # RandomOverSampling

# %%
# # ru = RandomUnderSampler() # undersampling
# # ru_X,ru_y = ru.fit_resample(X,y)
# ro = RandomOverSampler() # oversampling
# ro_X,ro_y = ro.fit_resample(X,y)
# # smote = SMOTE(random_state=42)# (Oversampling)
# # smote_X,smote_y = smote.fit_resample(X,y)
smt = SMOTETomek(random_state=42) #  (Combined)
smt_X,smt_y = smt.fit_resample(X,y)

# %%
smt_y.value_counts()
# Out:
# Risk_Category
# 0    1036
# 2    1029
# 1     970
# Name: count, dtype: int64

# %% [markdown]
# #  Train-Test Split (80% Training, 20% Testing)

# %%
# 2. Train-Test Split (80% Training, 20% Testing)
# X_train, X_test, y_train, y_test = train_test_split(ru_X,ru_y , test_size=0.2, random_state=42)
# X_train1, X_test1, y_train1, y_test1 = train_test_split(ro_X,ro_y , test_size=0.2, random_state=42)
X_train2, X_test2, y_train2, y_test2 = train_test_split(smt_X,smt_y  , test_size=0.2, random_state=42)
# X_train3, X_test3, y_train3, y_test3 = train_test_split(smt_X,smt_y , test_size=0.2, random_state=42)

# %%
X_train2.head(10)
# Out:
#       Average_Salary  Years_Experience  Education_Level  AI_Exposure_Index  \
# 1097          101020                21                3           0.780000
# 407           137334                 1                2           0.650000
# 2716           73958                25                2           0.535146
# 999            37203                28                0           0.470000
# 1222           37317                 0                0           0.620000
# 3004           37204                13                0           0.807179
# 2987           92266                22                2           0.631229
# 1641           81290                20                3           0.430000
# 7             117455                22                0           0.670000
# 700            72294                14                1           0.950000
#
#       Tech_Growth_Factor  Automation_Probability_2030   Skill_1   Skill_2  \
# ...

# %%
df.shape
# Out:
# (3000, 17)

# %%
X_train2.shape ,y_train2.shape
# Out:
# ((2428, 16), (2428,))

# %%
X_test2.shape, y_test2.shape
# Out:
# ((607, 16), (607,))

# %%
 y_train2
# Out:
# 1097    0
# 407     1
# 2716    2
# 999     1
# 1222    1
#        ..
# 1638    2
# 1095    0
# 1130    2
# 1294    0
# 860     1
# Name: Risk_Category, Length: 2428, dtype: int64

# %%
X_train2.head(10)
# Out:
#       Average_Salary  Years_Experience  Education_Level  AI_Exposure_Index  \
# 1097          101020                21                3           0.780000
# 407           137334                 1                2           0.650000
# 2716           73958                25                2           0.535146
# 999            37203                28                0           0.470000
# 1222           37317                 0                0           0.620000
# 3004           37204                13                0           0.807179
# 2987           92266                22                2           0.631229
# 1641           81290                20                3           0.430000
# 7             117455                22                0           0.670000
# 700            72294                14                1           0.950000
#
#       Tech_Growth_Factor  Automation_Probability_2030   Skill_1   Skill_2  \
# ...

# %%
 y_test2
# Out:
# 93      1
# 2714    2
# 1614    1
# 2010    0
# 2560    2
#        ..
# 365     1
# 2234    0
# 2258    0
# 2843    2
# 2252    0
# Name: Risk_Category, Length: 607, dtype: int64

# %% [markdown]
# # Feature Scaling

# %%
scaler = StandardScaler()
X_train2 = scaler.fit_transform(X_train2)
X_test2 = scaler.transform(X_test2)

# %% [markdown]
# # Train  Models

# %% [markdown]
# #  RandomForestClassifier model 1

# %%
# 3. Model Creation & Training
rf = RandomForestClassifier(n_estimators=100, random_state=42)

# %%
rf.fit(X_train2, y_train2)
# Out:
# RandomForestClassifier(random_state=42)

# %%
rf.score(X_train2, y_train2)
# Out:
# 1.0

# %%
rf.score(X_test2,y_test2)
# Out:
# 1.0

# %%
rf.predict(X_test2)
# Out:
# array([1, 2, 1, 0, 2, 0, 2, 2, 1, 1, 0, 1, 0, 0, 0, 1, 1, 1, 2, 2, 2, 2,
#        0, 0, 2, 1, 0, 2, 0, 0, 2, 0, 2, 1, 1, 1, 2, 0, 2, 2, 1, 2, 1, 2,
#        1, 1, 2, 0, 0, 0, 2, 2, 2, 1, 1, 1, 1, 2, 1, 1, 1, 0, 1, 2, 2, 0,
#        0, 1, 0, 2, 1, 1, 0, 2, 2, 0, 0, 1, 2, 2, 1, 0, 1, 0, 1, 0, 2, 2,
#        1, 1, 1, 2, 2, 0, 0, 1, 2, 0, 1, 0, 2, 1, 0, 1, 1, 2, 0, 0, 0, 0,
#        1, 1, 0, 1, 2, 2, 0, 1, 0, 2, 0, 2, 1, 1, 1, 2, 0, 2, 0, 2, 2, 1,
#        0, 1, 0, 1, 0, 0, 1, 2, 2, 1, 1, 1, 2, 0, 0, 0, 0, 1, 1, 0, 2, 1,
#        1, 1, 0, 1, 1, 2, 2, 1, 1, 0, 1, 2, 0, 2, 0, 0, 2, 2, 1, 0, 1, 0,
#        1, 1, 0, 0, 0, 0, 2, 2, 1, 1, 2, 0, 0, 1, 0, 0, 1, 1, 2, 2, 1, 1,
#        2, 0, 0, 2, 0, 2, 0, 0, 0, 2, 1, 2, 1, 1, 2, 2, 0, 1, 0, 2, 2, 2,
#        2, 1, 1, 1, 2, 0, 2, 2, 2, 2, 2, 2, 1, 1, 0, 1, 0, 1, 0, 0, 0, 1,
#        0, 0, 2, 1, 2, 2, 2, 2, 2, 0, 1, 1, 1, 1, 2, 0, 0, 0, 1, 2, 2, 1,
#        1, 0, 1, 0, 0, 0, 2, 0, 0, 0, 0, 0, 1, 1, 0, 2, 2, 2, 0, 2, 0, 2,
# ...

# %%
cf=confusion_matrix(y_test2,rf.predict(X_test2))
cf
# Out:
# array([[207,   0,   0],
#        [  0, 203,   0],
#        [  0,   0, 197]], dtype=int64)

# %%
target_names = "Risk_Category"

# %%
clf = RandomForestClassifier(random_state=42).fit(X_train2, y_train2)
y_pred = clf.predict(X_test2)
cm = confusion_matrix(y_test2, y_pred)

# %%
disp = ConfusionMatrixDisplay(
    confusion_matrix=cm, 
    display_labels=target_names)

# %%
# Confusion Matrix Plot
plt.figure(figsize=(6,4))
disp.plot(cmap=plt.cm.Greens, values_format='d')  # 'd' ensures integers are displayed
plt.title('Confusion Matrix')
plt.ylabel('Actual value')
plt.xlabel('Predicted Value')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 3
#       1 # Confusion Matrix Plot
#       2 plt.figure(figsize=(6,4))
# ----> 3 disp.plot(cmap=plt.cm.Greens, values_format='d')  # 'd' ensures integers are displayed
#       4 plt.title('Confusion Matrix')
#       5 plt.ylabel('Actual value')
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_plot\confusion_matrix.py:181, in ConfusionMatrixDisplay.plot(self, include_values, cmap, xticks_rotation, values_format, ax, colorbar, im_kw, text_kw)
#     179 if colorbar:
#     180     fig.colorbar(self.im_, ax=ax)
# --> 181 ax.set(
#     182     xticks=np.arange(n_classes),
#     183     yticks=np.arange(n_classes),
#     184     xticklabels=display_labels,
#     185     yticklabels=display_labels,
#     186     ylabel="True label",
#     187     xlabel="Predicted label",
#     188 )
# ...

# %%
cf
# Out:
# array([[207,   0,   0],
#        [  0, 203,   0],
#        [  0,   0, 197]], dtype=int64)

# %%
# Confusion Matrix Plot
plt.figure(figsize=(6,4))
sns.heatmap(cf,annot=True , fmt='d', cmap='Greens')
plt.title('Confusion Matrix')
plt.ylabel('Actual value')
plt.xlabel('Predicted Value')
plt.show()

# %%
# 4. Predictions (Testing)
y_pred = rf.predict(X_test2)

# %%
# 5. Performance Evaluation
accuracy = accuracy_score(y_test2, y_pred)
print(f"\nModel Accuracy: {accuracy * 100:.2f}%")
# Out:
# Model Accuracy: 100.00%

# %%
print("\nClassification Report:")
print(classification_report(y_test2, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       207
#            1       1.00      1.00      1.00       203
#            2       1.00      1.00      1.00       197
#
#     accuracy                           1.00       607
#    macro avg       1.00      1.00      1.00       607
# weighted avg       1.00      1.00      1.00       607

# %%
# Feature Importance 
importances = rf.feature_importances_
features = X.columns

# %%
# Sorting 
indices = np.argsort(importances)[::-1]

# %%
# Plotting
plt.figure(figsize=(12, 6))
plt.title("Feature Importance")
plt.bar(range(X.shape[1]), importances[indices], align="center")
plt.xticks(range(X.shape[1]), features[indices], rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# # LogisticRegression model 2

# %%
lr=LogisticRegression()
lr.fit(X_train2,y_train2)
# Out:
# LogisticRegression()

# %%
lr.score(X_train2,y_train2)
# Out:
# 0.9925864909390445

# %%
lr.score(X_test2,y_test2)
# Out:
# 0.9785831960461285

# %%
clr = confusion_matrix(y_test2,lr.predict(X_test2))
clr
# Out:
# array([[202,   5,   0],
#        [  2, 196,   5],
#        [  0,   1, 196]], dtype=int64)

# %%
# Confusion Matrix Plot
plt.figure(figsize=(6,4))
sns.heatmap(clr,annot=True , fmt='d', cmap='Greens')
plt.title('Confusion Matrix')
plt.ylabel('Actual value')
plt.xlabel('Predicted Value')
plt.show()

# %%
# 4. Predictions (Testing)
y_pred = lr.predict(X_test2)

# %%
# 5. Performance Evaluation
accuracy = accuracy_score(y_test2, y_pred)
print(f"\nModel Accuracy: {accuracy * 100:.2f}%")
# Out:
# Model Accuracy: 97.86%

# %%
print("\nClassification Report:")
print(classification_report(y_test2, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.98       207
#            1       0.97      0.97      0.97       203
#            2       0.98      0.99      0.98       197
#
#     accuracy                           0.98       607
#    macro avg       0.98      0.98      0.98       607
# weighted avg       0.98      0.98      0.98       607

# %% [markdown]
#  # DecisionTreeClassifier model 3

# %%
dt=DecisionTreeClassifier()
dt.fit(X_train2,y_train2)
# Out:
# DecisionTreeClassifier()

# %%
dt.score(X_train2,y_train2)
# Out:
# 1.0

# %%
dt.score(X_test2,y_test2)
# Out:
# 1.0

# %%
cdt = confusion_matrix(y_test2,dt.predict(X_test2))
cdt
# Out:
# array([[207,   0,   0],
#        [  0, 203,   0],
#        [  0,   0, 197]], dtype=int64)

# %%
# Confusion Matrix Plot
plt.figure(figsize=(6,4))
sns.heatmap(cdt,annot=True , fmt='d', cmap='Greens')
plt.title('Confusion Matrix')
plt.ylabel('Actual value')
plt.xlabel('Predicted Value')
plt.show()

# %%
# 4. Predictions (Testing)
y_pred = dt.predict(X_test2)

# %%
# 5. Performance Evaluation
accuracy = accuracy_score(y_test2, y_pred)
print(f"\nModel Accuracy: {accuracy * 100:.2f}%")
# Out:
# Model Accuracy: 100.00%

# %%
print("\nClassification Report:")
print(classification_report(y_test2, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       207
#            1       1.00      1.00      1.00       203
#            2       1.00      1.00      1.00       197
#
#     accuracy                           1.00       607
#    macro avg       1.00      1.00      1.00       607
# weighted avg       1.00      1.00      1.00       607

# %%
plt.figure(figsize=(8,8))
plot_tree(dt)
plt.show()

# %% [markdown]
# # KNeighborsClassifier model 4

# %%
knn=KNeighborsClassifier(n_neighbors=23)
knn.fit(X_train2,y_train2)
# Out:
# KNeighborsClassifier(n_neighbors=23)

# %%
knn.score(X_test2,y_test2)
# Out:
# 0.71499176276771

# %%
knn.score(X_train2,y_train2)
# Out:
# 0.7714168039538715

# %%
ckn = confusion_matrix(y_test2,knn.predict(X_test2))
ckn
# Out:
# array([[201,   6,   0],
#        [ 92,  38,  73],
#        [  0,   2, 195]], dtype=int64)

# %%
# Confusion Matrix Plot
plt.figure(figsize=(6,4))
sns.heatmap(ckn,annot=True , fmt='d', cmap='Greens')
plt.title('Confusion Matrix')
plt.ylabel('Actual value')
plt.xlabel('Predicted Value')
plt.show()

# %%
# 4. Predictions (Testing)
y_pred = knn.predict(X_test2)

# %%
# 5. Performance Evaluation
accuracy = accuracy_score(y_test2, y_pred)
print(f"\nModel Accuracy: {accuracy * 100:.2f}%")
# Out:
# Model Accuracy: 71.50%

# %%
print("\nClassification Report:")
print(classification_report(y_test2, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.69      0.97      0.80       207
#            1       0.83      0.19      0.31       203
#            2       0.73      0.99      0.84       197
#
#     accuracy                           0.71       607
#    macro avg       0.75      0.72      0.65       607
# weighted avg       0.75      0.71      0.65       607

# %%
for i in range(1,30):
    knn1 = KNeighborsClassifier(n_neighbors=i)
    knn1.fit(X_train2,y_train2)
    print(i,knn1.score(X_train2,y_train2)*100,knn1.score(X_test2,y_test2)*100)
# Out:
# 1 100.0 78.41845140032949
# 2 88.79736408566721 75.94728171334431
# 3 86.86161449752883 73.64085667215815
# 4 85.33772652388797 73.97034596375617
# 5 84.10214168039539 74.46457990115321
# 6 82.28995057660626 74.79406919275124
# 7 81.87808896210873 74.2998352553542
# 8 81.34266886326195 73.97034596375617
# 9 80.18945634266886 73.47611202635915
# 10 80.93080724876441 73.31136738056013
# 11 80.23064250411862 72.48764415156508
# 12 80.27182866556836 72.65238879736408
# 13 79.36573311367381 72.48764415156508
# 14 79.44810543657331 72.15815485996706
# 15 78.37726523887973 71.82866556836903
# 16 78.13014827018122 71.66392092257001
# 17 78.45963756177923 71.82866556836903
# 18 77.0181219110379 71.82866556836903
# 19 77.30642504118617 71.99341021416804
# 20 77.14168039538714 71.49917627677101
# 21 77.1004942339374 71.49917627677101
# 22 77.1004942339374 71.49917627677101
# 23 77.14168039538714 71.49917627677101
# 24 76.68863261943987 71.33443163097199
# 25 76.56507413509061 72.32289950576606
# ...

# %% [markdown]
# # SVC model 5

# %%
sv = SVC(kernel = "poly")
sv.fit(X_train2,y_train2)
# Out:
# SVC(kernel='poly')

# %%
sv.score(X_test2,y_test2)
# Out:
# 0.8682042833607908

# %%
sv.score(X_train2,y_train2)
# Out:
# 0.9575782537067545

# %%
csv = confusion_matrix(y_test2,sv.predict(X_test2))
csv
# Out:
# array([[197,  10,   0],
#        [ 30, 143,  30],
#        [  0,  10, 187]], dtype=int64)

# %%
# Confusion Matrix Plot
plt.figure(figsize=(6,4))
sns.heatmap(csv,annot=True , fmt='d', cmap='Greens')
plt.title('Confusion Matrix')
plt.ylabel('Actual value')
plt.xlabel('Predicted Value')
plt.show()

# %%
# 4. Predictions (Testing)
y_pred = sv.predict(X_test2)

# %%
# 5. Performance Evaluation
accuracy = accuracy_score(y_test2, y_pred)
print(f"\nModel Accuracy: {accuracy * 100:.2f}%")
# Out:
# Model Accuracy: 86.82%

# %%
print("\nClassification Report:")
print(classification_report(y_test2, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.95      0.91       207
#            1       0.88      0.70      0.78       203
#            2       0.86      0.95      0.90       197
#
#     accuracy                           0.87       607
#    macro avg       0.87      0.87      0.86       607
# weighted avg       0.87      0.87      0.86       607

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc
from sklearn.multiclass import OneVsRestClassifier

import matplotlib.pyplot as plt
import numpy as np

# %%
models = {
    "Logistic Regression": LogisticRegression(max_iter=1000),
    "Random Forest": RandomForestClassifier(n_estimators=100, random_state=42),
    "SVM": SVC(),
    "KNN": KNeighborsClassifier(n_neighbors=5),
    "DecisionTreeClassifier":DecisionTreeClassifier()
}

# %%
results = []

for name, model in models.items():
    
    model.fit(X_train2, y_train2)
    y_pred = model.predict(X_test2)
    
    acc = accuracy_score(y_test2, y_pred)
    pre = precision_score(y_test2, y_pred, average='weighted')
    rec = recall_score(y_test2, y_pred, average='weighted')
    f1  = f1_score(y_test2, y_pred, average='weighted')
    
    results.append([name, acc, pre, rec, f1])

# %%
results_df = pd.DataFrame(
    results,
    columns=['Model', 'Accuracy', 'Precision', 'Recall', 'F1-Score']
)

results_df
# Out:
#                     Model  Accuracy  Precision    Recall  F1-Score
# 0     Logistic Regression  0.978583   0.978650  0.978583  0.978564
# 1           Random Forest  1.000000   1.000000  1.000000  1.000000
# 2                     SVM  0.958814   0.958758  0.958814  0.958782
# 3                     KNN  0.744646   0.755205  0.744646  0.712164
# 4  DecisionTreeClassifier  1.000000   1.000000  1.000000  1.000000

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.bar(results_df['Model'], results_df['Accuracy'])
plt.xlabel('Models')
plt.ylabel('Accuracy')
plt.title('Accuracy Comparison of ML Models')
plt.xticks(rotation=45)
plt.show()

# %%
import numpy as np

x = np.arange(len(results_df['Model']))
width = 0.25

plt.figure(figsize=(10,5))

plt.bar(x - width, results_df['Precision'], width, label='Precision')
plt.bar(x, results_df['Recall'], width, label='Recall')
plt.bar(x + width, results_df['F1-Score'], width, label='F1-Score')

plt.xticks(x, results_df['Model'], rotation=45)
plt.xlabel('Models')
plt.ylabel('Score')
plt.title('Precision, Recall & F1-Score Comparison')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(9,5))

plt.plot(results_df['Model'], results_df['Accuracy'], marker='o', label='Accuracy')
plt.plot(results_df['Model'], results_df['Precision'], marker='o', label='Precision')
plt.plot(results_df['Model'], results_df['Recall'], marker='o', label='Recall')
plt.plot(results_df['Model'], results_df['F1-Score'], marker='o', label='F1-Score')

plt.xlabel('Models')
plt.ylabel('Score')
plt.title('Overall Performance Trend of Models')
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(7,4))
plt.imshow(results_df[['Accuracy','Precision','Recall','F1-Score']], aspect='auto')

plt.colorbar(label='Score')
plt.xticks(range(4), ['Accuracy','Precision','Recall','F1-Score'])
plt.yticks(range(len(results_df['Model'])), results_df['Model'])

plt.title('Performance Heatmap of ML Models')
plt.show()
